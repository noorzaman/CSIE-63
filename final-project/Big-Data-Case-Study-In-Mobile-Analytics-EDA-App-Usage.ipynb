# %%
import os
import pyspark.mllib
import numpy as np
import matplotlib.pyplot
import seaborn as sns
import pyspark
import urllib
import pandas as pd

from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext, SparkSession, Row
from pyspark.sql.types import *
from pyspark.sql.functions import *

from IPython.display import display, HTML
sns.set_style('whitegrid')
# %matplotlib inline

get_ipython().magic(u'pylab inline')
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['rand', 'cbrt', 'rank', 'cosh', 'hypot', 'tan', 'array', 'size', 'isnan', 'randn', 'log', 'floor', 'sum', 'sqrt', 'degrees', 'split', 'rint', 'log10', 'sin', 'repeat', 'log2', 'cos', 'ceil', 'broadcast', 'sinh', 'trunc', 'expm1', 'tanh', 'radians', 'exp', 'log1p', 'mean']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from IPython.display import Image
Image(filename='RelationalDatabasesFlow.jpg')

# %% [markdown]
# # Metrics
# 1. Most Active Apps
# 2. Most Installed Apps
# 3. Most Installed and Active Apps
# 4. apps_per_device_count
# 5. apps_per_event_avg
# 6. apps_active_per_device_count
# 7. apps_active_per_event_avg
# 8. categories_per_device_count
# 9. app_per_device_count
# 10. categories_per_app_avg

# %%
### Initialize streaming context
conf = SparkConf()\
                .setMaster("local[2]")\
                .setAppName("MobileAnalyticsEDAAppUsage")\
                .set("spark.executor.memory", "6g")\
                .set("spark.driver.memory", "6g")
sc = SparkContext(conf=conf)
sc.setLogLevel("ERROR")
sqlContext = SQLContext(sc)
spark = SparkSession.builder.appName("spark play").getOrCreate()

# %% [markdown]
# # Data Gathering

# %%
phone_brand_model_csv = "data/phone_brand_device_model_key.csv"
gender_age_train_csv = "data/gender_age_train.csv"
gender_age_test_csv = "data/gender_age_test.csv"
events_csv = "data/events.csv"
app_events_csv = "data/app_events.csv"
app_labels_csv ="data/app_labels.csv"
label_categories_csv = "data/label_categories.csv"

train_CSV ="data/train"
test_CSV ="data/test"

# %%
# gender_age
# events
# app_events
# app_labels
# app_categories

# %%
app_events = spark.read.csv(app_events_csv, header=True, mode="DROPMALFORMED", inferSchema='true', encoding="utf-8").persist()
app_events.show()
# Out:
# +--------+--------------------+------------+---------+
# |event_id|              app_id|is_installed|is_active|
# +--------+--------------------+------------+---------+
# |       2| 5927333115845830913|           1|        1|
# |       2|-5720078949152207372|           1|        0|
# |       2|-1633887856876571208|           1|        0|
# |       2| -653184325010919369|           1|        1|
# |       2| 8693964245073640147|           1|        1|
# |       2| 4775896950989639373|           1|        1|
# |       2|-8022267440849930066|           1|        0|
# |       2| 9112463267739110219|           1|        0|
# |       2|-3725672010020973973|           1|        0|
# |       2| 7167114343576723123|           1|        1|
# |       2|  487766649788038994|           1|        0|
# |       2| 7460082553072507347|           1|        0|
# |       2|  628020936226491308|           1|        0|
# |       2|  701031210314548601|           1|        0|
# |       2|-1758857579862594461|           1|        0|
# |       2| 4348659952760821294|           1|        0|
# |       2|-8942695423876075857|           1|        0|
# |       2| 5497109940653330488|           1|        1|
# |       2| 3717049149426646122|           1|        0|
# |       6|-7377004479023402858|           1|        1|
# +--------+--------------------+------------+---------+
# only showing top 20 rows

# %%
print "shape:" + str(((app_events.count(), len(app_events.columns))))
# Out:
# shape:(32473067, 4)

# %%
print app_events.select("event_id").distinct().count()
# Out:
# 1488096

# %%
print app_events.select("app_id").distinct().count()
# Out:
# 19237

# %%
app_events_cleaned = app_events.drop_duplicates()

# %%
print "shape:" + str(((app_events_cleaned.count(), len(app_events_cleaned.columns))))
# Out:
# shape:(32473067, 4)

# %% [markdown]
# # Most App Installs

# %%
app_events_installed = app_events.filter((col("is_installed") == 1)) \
                              .groupby('app_id') \
                              .agg({"is_installed":"sum"})\
                              .rdd.sortBy(lambda x: x[1], ascending=False)\
                              .toDF()\
                              .toPandas()\
                              .set_index("app_id")
app_events_installed
# Out:
#                       sum(is_installed)
# app_id
#  8693964245073640147            1151391
#  5927333115845830913             898788
#  4348659952760821294             795995
#  628020936226491308              620659
#  3433289601737013244             373186
# -2320783822570582843             295619
#  5729517255058371973             272353
#  3683147815759994238             265823
#  6284164581582112235             260639
#  8948670408023620661             254316
# -3955212733485100109             246759
#  7348340405200054701             241397
#  3717049149426646122             232618
#  4244331088397413857             226472
# -5720078949152207372             221899
#  7460082553072507347             221756
# -6590029937880196169             220237
# -538061441862183033              215628
#  33792862810792679               193287
#  9112463114311278255             192712
# -653184325026622087              184246
# -5472633337921616096             177964
# -196592189248911642              176140
# -6689096779184407258             172843
# -7377004479023402858             171707
# -8504475857937456387             170511
# -5839858269967688123             164802
# -5305696816021977482             152631
#  7167114343576723123             151790
#  4521626599305779338             146025
# ...                                 ...
# -6616258008461713895                  1
#  6666573793351781537                  1
#  8430928725029775964                  1
#  6067083498065016387                  1
#  7405285763666174708                  1
# -1288074624633886755                  1
#  1823364655528464682                  1
# -7131954133420224497                  1
#  7795452358247521674                  1
# -8871570042097939631                  1
#  8770023716524959213                  1
#  5965929697251156692                  1
#  8047569250474295652                  1
#  4327671332967112082                  1
# -456061990877573263                   1
#  2077168350478511526                  1
#  671297026616592374                   1
# -1953152898253667956                  1
#  813451995784503950                   1
#  6995828889374619591                  1
# -3181567103579567022                  1
#  4494668982275962092                  1
#  9159628231441891168                  1
# -531755172691282905                   1
#  4942918651541063095                  1
#  8533713099104431217                  1
# -7680538372419902188                  1
# -5522967220292116422                  1
#  3600592630275118563                  1
#  1984860280938452364                  1
#
# [19237 rows x 1 columns]

# %%
mpl.rcParams['figure.figsize'] = (15.0, 6.0)
app_events_installed[0:50].plot(kind = 'bar')

# %%
app_events_installed = app_events.filter((col("is_installed") == 1)) \
                              .groupby('app_id') \
                              .agg({"is_installed":"sum"})\
                              .rdd.sortBy(lambda x: x[1], ascending=False)\
                              .toDF()\
                              .toPandas()
app_events_installed
# Out:
#                     app_id  sum(is_installed)
# 0      8693964245073640147            1151391
# 1      5927333115845830913             898788
# 2      4348659952760821294             795995
# 3       628020936226491308             620659
# 4      3433289601737013244             373186
# 5     -2320783822570582843             295619
# 6      5729517255058371973             272353
# 7      3683147815759994238             265823
# 8      6284164581582112235             260639
# 9      8948670408023620661             254316
# 10    -3955212733485100109             246759
# 11     7348340405200054701             241397
# 12     3717049149426646122             232618
# 13     4244331088397413857             226472
# 14    -5720078949152207372             221899
# 15     7460082553072507347             221756
# 16    -6590029937880196169             220237
# 17     -538061441862183033             215628
# 18       33792862810792679             193287
# 19     9112463114311278255             192712
# 20     -653184325026622087             184246
# 21    -5472633337921616096             177964
# 22     -196592189248911642             176140
# 23    -6689096779184407258             172843
# 24    -7377004479023402858             171707
# 25    -8504475857937456387             170511
# 26    -5839858269967688123             164802
# 27    -5305696816021977482             152631
# 28     7167114343576723123             151790
# 29     4521626599305779338             146025
# ...                    ...                ...
# 19207 -6616258008461713895                  1
# 19208  6666573793351781537                  1
# 19209  8430928725029775964                  1
# 19210  6067083498065016387                  1
# 19211  7405285763666174708                  1
# 19212 -1288074624633886755                  1
# 19213  1823364655528464682                  1
# 19214 -7131954133420224497                  1
# 19215  7795452358247521674                  1
# 19216 -8871570042097939631                  1
# 19217  8770023716524959213                  1
# 19218  5965929697251156692                  1
# 19219  8047569250474295652                  1
# 19220  4327671332967112082                  1
# 19221  -456061990877573263                  1
# 19222  2077168350478511526                  1
# 19223   671297026616592374                  1
# 19224 -1953152898253667956                  1
# 19225   813451995784503950                  1
# 19226  6995828889374619591                  1
# 19227 -3181567103579567022                  1
# 19228  4494668982275962092                  1
# 19229  9159628231441891168                  1
# 19230  -531755172691282905                  1
# 19231  4942918651541063095                  1
# 19232  8533713099104431217                  1
# 19233 -7680538372419902188                  1
# 19234 -5522967220292116422                  1
# 19235  3600592630275118563                  1
# 19236  1984860280938452364                  1
#
# [19237 rows x 2 columns]

# %%
# apps_installed_histogram = app_events.filter((col("is_installed") == 1)).select("app_id").rdd.flatMap(lambda x: x).histogram(20)
# pd.DataFrame(list(zip(*apps_installed_histogram )), columns=['bin', 'frequency']).set_index('bin').plot(kind='bar');

# pd.DataFrame(list(zip(*gre_histogram)), columns=['bin', 'frequency'])

# %%
startValues, counts = app_events.filter((col("is_installed") == 1))\
                              .select("app_id")\
                              .rdd.flatMap(lambda x: x) \
                              .histogram(5)
#                                 .groupby('app_id') \
#                               .agg({"is_installed":"sum"})\
#                               
                              
# list(zip(*apps_installed_histogram )
# print apps_installed_histogram

# %%
zippedValues = list(zip(startValues, counts))
# val zippedValues = startValues.zip(counts)
# case class HistRow(startPoint:Double,count:Long)
# val rowRDD = zippedValues.map( value => HistRow(value._1,value._2))
# val histDf = sparkSession.createDataFrame(rowRDD)
# histDf.createOrReplaceTempView("histogramTable")
print zippedValues

# %%
app_events_histogram = app_events.filter((col("is_installed") == 1)).select("app_id").sample(False, 0.1).toPandas().plot(kind='hist', bins=10, facecolor='lightblue')
# print app_events_histogram

# %% [markdown]
# # Most Active Apps

# %%
app_events_active = app_events.filter((col("is_active") == 1)) \
                              .groupby('app_id') \
                              .agg({"is_active":"sum"})\
                              .rdd.sortBy(lambda x: x[1], ascending=False)\
                              .toDF()\
                              .toPandas()\
                              .set_index("app_id")
app_events_active
# Out:
#                       sum(is_active)
# app_id
#  8693964245073640147          918156
#  5927333115845830913          617102
#  4348659952760821294          427541
#  3433289601737013244          373186
#  628020936226491308           349882
#  6284164581582112235          260639
#  8948670408023620661          254316
# -3955212733485100109          244681
# -538061441862183033           215627
# -2320783822570582843          198384
# -5472633337921616096          144413
#  7348340405200054701          141311
# -8504475857937456387          130154
# -5368809411346728624          121296
#  5516228268441717785          115172
#  6956699582426139508          102206
# -6793861127573349654           97471
#  8557198901083791098           93788
#  7167114343576723123           91163
# -6590029937880196169           89983
#  5099453940784075687           88785
#  1665047061121005617           86558
#  7460082553072507347           85914
#  33792862810792679             66130
#  7378912078908392888           65447
#  2689721421138748406           64379
# -5924787280098922359           63313
# -1633938282180439957           62640
# -6799509164833422300           60758
# -5720078949152207372           59245
# ...                              ...
# -9006565540355077304               1
# -2977664040393830560               1
#  1409254621165593949               1
#  7208062525946643265               1
# -5980312273529115500               1
# -971722085361943427                1
# -39424798187125531                 1
# -8489750320166337759               1
#  4090746997205385275               1
#  8001915132264668097               1
# -1442117567617756336               1
# -412643789390721152                1
#  4626674442758687240               1
#  2062889659280340944               1
#  4674092782761111904               1
# -3520036191199316147               1
#  2842134841982006010               1
#  3175387644714845207               1
#  4942918651541063095               1
# -4959585135259373648               1
#  4570845065620218689               1
# -304417543313629621                1
# -624826928176350585                1
# -7680538372419902188               1
#  977785572754631945                1
# -8638829707219305108               1
#  262080049982937084                1
#  6245880394442240780               1
# -616240409235704923                1
#  1144537413399993927               1
#
# [10582 rows x 1 columns]

# %% [markdown]
# # Most Active Apps

# %%
mpl.rcParams['figure.figsize'] = (15.0, 6.0)
app_events_active[0:50].plot(kind = 'bar', color = 'red')

# %%
apps_installed_active = app_events.filter((col("is_installed") == 1) & (col("is_active") == 1))\
                                  .groupby('app_id') \
                                  .agg({"is_installed":"sum"})\
                                  .rdd.sortBy(lambda x: x[1], ascending=False)\
                                  .toDF()\
                                  .toPandas()\
                                  .set_index("app_id")
apps_installed_active
# Out:
#                       sum(is_installed)
# app_id
#  8693964245073640147             918156
#  5927333115845830913             617102
#  4348659952760821294             427541
#  3433289601737013244             373186
#  628020936226491308              349882
#  6284164581582112235             260639
#  8948670408023620661             254316
# -3955212733485100109             244681
# -538061441862183033              215627
# -2320783822570582843             198384
# -5472633337921616096             144413
#  7348340405200054701             141311
# -8504475857937456387             130154
# -5368809411346728624             121296
#  5516228268441717785             115172
#  6956699582426139508             102206
# -6793861127573349654              97471
#  8557198901083791098              93788
#  7167114343576723123              91163
# -6590029937880196169              89983
#  5099453940784075687              88785
#  1665047061121005617              86558
#  7460082553072507347              85914
#  33792862810792679                66130
#  7378912078908392888              65447
#  2689721421138748406              64379
# -5924787280098922359              63313
# -1633938282180439957              62640
# -6799509164833422300              60758
# -5720078949152207372              59245
# ...                                 ...
# -9006565540355077304                  1
# -2977664040393830560                  1
#  1409254621165593949                  1
#  7208062525946643265                  1
# -5980312273529115500                  1
# -971722085361943427                   1
# -39424798187125531                    1
# -8489750320166337759                  1
#  4090746997205385275                  1
#  8001915132264668097                  1
# -1442117567617756336                  1
# -412643789390721152                   1
#  4626674442758687240                  1
#  2062889659280340944                  1
#  4674092782761111904                  1
# -3520036191199316147                  1
#  2842134841982006010                  1
#  3175387644714845207                  1
#  4942918651541063095                  1
# -4959585135259373648                  1
#  4570845065620218689                  1
# -304417543313629621                   1
# -624826928176350585                   1
# -7680538372419902188                  1
#  977785572754631945                   1
# -8638829707219305108                  1
#  262080049982937084                   1
#  6245880394442240780                  1
# -616240409235704923                   1
#  1144537413399993927                  1
#
# [10582 rows x 1 columns]

# %%
mpl.rcParams['figure.figsize'] = (15.0, 6.0)
apps_installed_active[0:50].plot(kind = 'bar', color = 'purple')

# %% [markdown]
# # Explore App Categories

# %%
label_categories = spark.read.csv(label_categories_csv, header=True, mode="DROPMALFORMED", inferSchema='true', encoding="utf-8").persist()
print label_categories.count()
label_categories.show()
# Out:
# 930
# +--------+--------------------+---------------+
# |label_id|            category|label_itunes_id|
# +--------+--------------------+---------------+
# |       1|                null|             26|
# |       2|      game-game type|              8|
# |       3|    game-Game themes|              8|
# |       4|      game-Art Style|              8|
# |       5|   game-Leisure time|              8|
# |       6| game-Cutting things|              8|
# |       7|  game-Finding fault|              8|
# |       8|game-stress reliever|              8|
# |       9|            game-pet|              8|
# |      10|         game-Answer|              8|
# |      11|        game-Fishing|              8|
# |      12|game-Music and Dance|              8|
# |      13|         game-Puzzle|              8|
# |      14|game-Adventure pu...|              8|
# |      15| game-Parkour Racing|              8|
# |      16|        game-Parkour|              8|
# |      17|         game-Racing|              8|
# |      18|     game-Motorcycle|              8|
# |      19|         game-Rowing|              8|
# |      20|       game-aircraft|              8|
# +--------+--------------------+---------------+
# only showing top 20 rows

# %%
print "shape:" + str(((label_categories.count(), len(label_categories.columns))))
# Out:
# shape:(930, 3)

# %%
print label_categories.select("category").distinct().count()
# Out:
# 836

# %%
print label_categories.filter(col("category") == "unknown").count()
# Out:
# 26

# %%
print label_categories.filter(col("category").isNull()).count()
# Out:
# 3

# %% [markdown]
# # Combining App/Categories Data

# %%
app_labels = spark.read.csv(app_labels_csv, header=True, mode="DROPMALFORMED", inferSchema='true', encoding="utf-8").persist()
print app_labels.count()
app_labels.show()
# Out:
# 459943
# +--------------------+--------+
# |              app_id|label_id|
# +--------------------+--------+
# | 7324884708820027918|     251|
# |-4494216993218550286|     251|
# | 6058196446775239644|     406|
# | 6058196446775239644|     407|
# | 8694625920731541625|     406|
# | 8694625920731541625|     407|
# | 1977658975649789753|     406|
# | 1977658975649789753|     407|
# | 7311663864768030840|     256|
# | 5902120154267999338|     256|
# | 2441810024319437760|     256|
# | 8378607170315253667|     261|
# |-7468212093586159919|     256|
# |-6493194103110420302|     253|
# | 3089609407449461199|     256|
# | 2705437723590691734|     253|
# |-1919793861139224050|     256|
# | 4955831798976247953|     256|
# |-7306728226531308671|     256|
# | 1078279648391910971|     256|
# +--------------------+--------+
# only showing top 20 rows

# %%
app_label_categories = app_labels.join(label_categories, "label_id", "left_outer").persist()
print app_label_categories.count()
app_label_categories.show()
# Out:
# 459943
# +--------+--------------------+---------------+---------------+
# |label_id|              app_id|       category|label_itunes_id|
# +--------+--------------------+---------------+---------------+
# |     251| 7324884708820027918|        Finance|              6|
# |     251|-4494216993218550286|        Finance|              6|
# |     406| 6058196446775239644|        unknown|             26|
# |     407| 6058196446775239644|DS_P2P net loan|              6|
# |     406| 8694625920731541625|        unknown|             26|
# |     407| 8694625920731541625|DS_P2P net loan|              6|
# |     406| 1977658975649789753|        unknown|             26|
# |     407| 1977658975649789753|DS_P2P net loan|              6|
# |     256| 7311663864768030840|     Securities|              6|
# |     256| 5902120154267999338|     Securities|              6|
# |     256| 2441810024319437760|     Securities|              6|
# |     261| 8378607170315253667| Lottery ticket|              6|
# |     256|-7468212093586159919|     Securities|              6|
# |     253|-6493194103110420302|            IMF|              6|
# |     256| 3089609407449461199|     Securities|              6|
# |     253| 2705437723590691734|            IMF|              6|
# |     256|-1919793861139224050|     Securities|              6|
# |     256| 4955831798976247953|     Securities|              6|
# |     256|-7306728226531308671|     Securities|              6|
# |     256| 1078279648391910971|     Securities|              6|
# +--------+--------------------+---------------+---------------+
# only showing top 20 rows

# %%
print "shape:" + str(((app_label_categories.count(), len(app_label_categories.columns))))
# Out:
# shape:(459943, 4)

# %% [markdown]
# # Refrences
# - http://blog.madhukaraphatak.com/statistical-data-exploration-spark-part-2/
