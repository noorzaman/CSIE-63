# %% [markdown]
# ## Cleaning Data from Talking Data Kaggle competition for Dashboard
#
# This notebook does the necessary data cleaning to output dashboard_data.csv and dashboard_data.json using both the given datasets in the competition and also real-world map data from China.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from shapely.geometry import Point, shape
import json

# %%
a = os.getcwd()

path1 = a + '\data\gender_age_train.csv'
path2 = a + '\data\phone_brand_device_model.csv'
path3 = a + '\data\events.csv'

train = pd.read_csv(path1)
phone_brand = pd.read_csv(path2)
events = pd.read_csv(path3)

with open(a + '\data\china_provinces_en.json') as data_file:
    provinces_json = json.load(data_file)
    
train.head()
# Out:
#              device_id gender  age   group
# 0 -8076087639492063270      M   35  M32-38
# 1 -2897161552818060146      M   35  M32-38
# 2 -8260683887967679142      M   35  M32-38
# 3 -4938849341048082022      M   30  M29-31
# 4   245133531816851882      M   30  M29-31

# %%
n_samples = 30000
top_10_brands_en = {'华为':'Huawei', '小米':'Xiaomi', '三星':'Samsung', 'vivo':'vivo', 'OPPO':'OPPO', 
                    '魅族':'Meizu', '酷派':'Coolpad', '乐视':'LeEco', '联想':'Lenovo', 'HTC':'HTC'}

df = train.merge(events, how='left', on='device_id').merge(phone_brand, how='left', on='device_id')
df = df[df['longitude'] != 0].sample(n=n_samples)
df['phone_brand_en'] = df['phone_brand'].apply(lambda phone_brand: top_10_brands_en[phone_brand] if (phone_brand in top_10_brands_en) else 'Other')
df.head()
# Out:
#                    device_id gender  age   group   event_id  \
# 2365    -1516688507910543815      F   43    F43+  1486215.0
# 444970     31208013033799294      F   30  F29-32   851929.0
# 92676    3862448815156123127      F   29  F29-32   778630.0
# 1060688  8516510612349919591      F   29  F29-32  1578040.0
# 1084390 -1147337202699083457      M   23  M23-26   706264.0
#
#                    timestamp  longitude  latitude phone_brand device_model  \
# 2365     2016-05-02 20:06:04     118.34     34.35          华为          麦芒3
# 444970   2016-05-05 16:36:11     113.78     23.02        vivo         X5SL
# 92676    2016-05-06 21:33:18     120.72     27.82          小米      note顶配版
# 1060688  2016-05-03 11:19:40     114.55     38.00          华为         荣耀3C
# 1084390  2016-05-06 11:39:27     110.93     22.35          小米         MI 4
#
#         phone_brand_en
# 2365            Huawei
# 444970            vivo
# 92676           Xiaomi
# 1060688         Huawei
# 1084390         Xiaomi

# %%
def get_age_segment(age):
    if age <= 22:
        return '22-'
    elif age <= 26:
        return '23-26'
    elif age <= 28:
        return '27-28'
    elif age <= 32:
        return '29-32'
    elif age <= 38:
        return '33-38'
    else:
        return '39+'

df['age_segment'] = df['age'].apply(lambda age: get_age_segment(age))
df.head()
# Out:
#                    device_id gender  age   group   event_id  \
# 2365    -1516688507910543815      F   43    F43+  1486215.0
# 444970     31208013033799294      F   30  F29-32   851929.0
# 92676    3862448815156123127      F   29  F29-32   778630.0
# 1060688  8516510612349919591      F   29  F29-32  1578040.0
# 1084390 -1147337202699083457      M   23  M23-26   706264.0
#
#                    timestamp  longitude  latitude phone_brand device_model  \
# 2365     2016-05-02 20:06:04     118.34     34.35          华为          麦芒3
# 444970   2016-05-05 16:36:11     113.78     23.02        vivo         X5SL
# 92676    2016-05-06 21:33:18     120.72     27.82          小米      note顶配版
# 1060688  2016-05-03 11:19:40     114.55     38.00          华为         荣耀3C
# 1084390  2016-05-06 11:39:27     110.93     22.35          小米         MI 4
#
#         phone_brand_en age_segment
# 2365            Huawei         39+
# 444970            vivo       29-32
# 92676           Xiaomi       29-32
# 1060688         Huawei       29-32
# 1084390         Xiaomi       23-26

# %%
def get_location(longitude, latitude, provinces_json):
    point = Point(longitude,latitude)
    
    for record in provinces_json['features']:
        polygon = shape(record['geometry'])
        if polygon.contains(point):
            return record['properties']['name']
    return 'other'

# %%
df['location'] = df.apply(lambda row: get_location(row['longitude'], row['latitude'], provinces_json), axis=1)

# %%
pd.to_datetime(df['timestamp'], unit='ns')

#df['timestamp'] = pd.to_datetime(df['timestamp'],unit='ms')
# Out:
# 2365      2016-05-02 20:06:04
# 444970    2016-05-05 16:36:11
# 92676     2016-05-06 21:33:18
# 1060688   2016-05-03 11:19:40
# 1084390   2016-05-06 11:39:27
# 50735                     NaT
# 816924    2016-05-01 20:10:59
# 1007917   2016-05-05 09:56:48
# 785678    2016-05-05 23:49:55
# 830953    2016-05-05 09:38:02
# 377196    2016-05-02 01:25:06
# 235220    2016-05-04 22:53:08
# 1196569   2016-05-06 07:07:57
# 1236503   2016-05-03 22:05:07
# 169153    2016-05-04 07:37:10
# 379729    2016-05-03 14:08:13
# 245130    2016-05-06 22:48:58
# 1243569   2016-05-01 11:41:58
# 801333    2016-05-04 15:21:41
# 1239852   2016-05-05 20:07:41
# 114436    2016-05-06 12:27:54
# 322461    2016-05-02 11:06:32
# 972011    2016-05-03 08:13:02
# 382600    2016-05-02 11:41:27
# 308532    2016-05-07 12:40:01
# 43214                     NaT
# 420969    2016-05-07 04:17:19
# 920682    2016-05-05 09:42:22
# 313317    2016-05-01 20:00:08
# 895925    2016-05-03 22:17:31
#                   ...
# 336316                    NaT
# 107919    2016-05-06 12:05:04
# 158525    2016-05-03 08:43:51
# 886587    2016-05-01 07:36:19
# 761955    2016-05-05 10:57:16
# 989962    2016-05-02 23:48:19
# 1181305   2016-05-03 19:11:28
# 307595    2016-05-05 13:43:36
# 1102600   2016-05-02 20:28:28
# 693124    2016-05-07 18:03:52
# 206884    2016-05-03 16:46:25
# 445240    2016-05-03 07:46:51
# 1041633   2016-05-07 19:32:22
# 641631    2016-05-04 10:04:03
# 1191132   2016-05-05 04:18:31
# 251978    2016-05-02 12:54:57
# 908167    2016-05-06 20:55:41
# 798825    2016-05-06 19:40:05
# 1235688   2016-05-05 06:58:32
# 421350    2016-05-04 09:01:49
# 50513                     NaT
# 80786     2016-05-03 22:13:12
# 15215     2016-05-05 00:25:16
# 198223    2016-05-03 21:44:06
# 775015    2016-05-04 13:29:38
# 1206730   2016-05-02 17:37:24
# 666801    2016-05-03 09:51:35
# 667086    2016-05-01 04:49:35
# 28788     2016-05-04 20:58:31
# 264979    2016-05-01 18:09:58
# Name: timestamp, dtype: datetime64[ns]

# %%
df.to_csv(a + "data\\dashboard_data.csv",)

# %%
cols_to_keep = ['timestamp', 'longitude', 'latitude', 'phone_brand_en', 'gender', 'age_segment', 'location']
df_clean = df[cols_to_keep].dropna()
df_clean.head()
# Out:
#                    timestamp  longitude  latitude phone_brand_en gender  \
# 2365     2016-05-02 20:06:04     118.34     34.35         Huawei      F
# 444970   2016-05-05 16:36:11     113.78     23.02           vivo      F
# 92676    2016-05-06 21:33:18     120.72     27.82         Xiaomi      F
# 1060688  2016-05-03 11:19:40     114.55     38.00         Huawei      F
# 1084390  2016-05-06 11:39:27     110.93     22.35         Xiaomi      M
#
#         age_segment   location
# 2365            39+    Jiangsu
# 444970        29-32  Guangdong
# 92676         29-32   Zhejiang
# 1060688       29-32      Hebei
# 1084390       23-26  Guangdong

# %%
df_clean.to_json(a + "\\data\\dashboard_data.json",orient='records')

# %%
df_clean.head(50)
# Out:
#                    timestamp  longitude  latitude phone_brand_en gender  \
# 2365     2016-05-02 20:06:04     118.34     34.35         Huawei      F
# 444970   2016-05-05 16:36:11     113.78     23.02           vivo      F
# 92676    2016-05-06 21:33:18     120.72     27.82         Xiaomi      F
# 1060688  2016-05-03 11:19:40     114.55     38.00         Huawei      F
# 1084390  2016-05-06 11:39:27     110.93     22.35         Xiaomi      M
# 816924   2016-05-01 20:10:59     116.59     35.43        Samsung      M
# 1007917  2016-05-05 09:56:48     116.13     38.18         Xiaomi      M
# 785678   2016-05-05 23:49:55     115.95     39.72         Huawei      M
# 830953   2016-05-05 09:38:02     119.79     33.46        Samsung      F
# 377196   2016-05-02 01:25:06     114.12     22.62         Huawei      M
# 235220   2016-05-04 22:53:08     114.04     22.62          Meizu      M
# 1196569  2016-05-06 07:07:57     120.20     30.29           OPPO      M
# 1236503  2016-05-03 22:05:07     113.80     34.04         Xiaomi      M
# 169153   2016-05-04 07:37:10     117.30     34.23          LeEco      M
# 379729   2016-05-03 14:08:13     112.01     27.67        Coolpad      F
# 245130   2016-05-06 22:48:58     106.24     30.01         Huawei      F
# 1243569  2016-05-01 11:41:58     105.56     30.07        Coolpad      M
# 801333   2016-05-04 15:21:41     112.56     33.00         Huawei      M
# 1239852  2016-05-05 20:07:41     113.04     22.51           OPPO      M
# 114436   2016-05-06 12:27:54     120.19     30.21         Huawei      M
# 322461   2016-05-02 11:06:32     106.03     31.35         Xiaomi      M
# 972011   2016-05-03 08:13:02     111.12     37.50         Huawei      M
# 382600   2016-05-02 11:41:27     107.01     39.38           vivo      F
# 308532   2016-05-07 12:40:01     119.23     32.25           vivo      F
# 420969   2016-05-07 04:17:19     119.43     32.21          Meizu      M
# 920682   2016-05-05 09:42:22     111.02     34.68         Huawei      M
# 313317   2016-05-01 20:00:08     106.44     29.56         Xiaomi      M
# 895925   2016-05-03 22:17:31     116.41     40.02         Huawei      M
# 487165   2016-05-03 20:56:02     114.89     30.41         Xiaomi      M
# 859085   2016-05-06 08:39:55     120.56     32.38         Huawei      F
# 1257499  2016-05-01 10:06:34     115.36     33.26         Xiaomi      M
# 958436   2016-05-07 17:59:13     117.51     36.72        Samsung      M
# 750988   2016-05-05 19:49:30     114.18     22.95           vivo      M
# 348120   2016-05-01 14:21:52     113.07     23.01           OPPO      M
# 1133333  2016-05-07 16:42:49       1.00      1.00          Meizu      M
# 657903   2016-05-07 20:57:52     117.13     39.23          Meizu      F
# 1087521  2016-05-06 22:33:52     116.98     36.71         Huawei      F
# 1077656  2016-05-04 13:16:33     116.50     39.92         Huawei      F
# 970372   2016-05-02 13:34:06     111.65     40.80           OPPO      M
# 991867   2016-05-05 09:02:31     110.02     20.90         Xiaomi      M
# 231921   2016-05-04 09:53:16     113.30     22.73        Coolpad      F
# 1128470  2016-05-02 16:48:40     111.21     27.85           OPPO      M
# 1009314  2016-05-03 18:52:02     106.19     29.27           vivo      M
# 969198   2016-05-07 08:25:23     117.29     39.09         Huawei      F
# 362726   2016-05-01 09:49:48     120.12     29.40          Other      M
# 1044099  2016-05-07 08:58:47     120.65     42.85           vivo      M
# 1072618  2016-05-04 08:15:40     104.71     30.16         Xiaomi      M
# 380034   2016-05-01 10:13:30     116.86     38.31         Xiaomi      M
# 786254   2016-05-01 00:17:19     104.72     31.75         Huawei      M
# 769880   2016-05-05 17:28:35     111.32     30.73         Huawei      F
#
#         age_segment        location
# 2365            39+         Jiangsu
# 444970        29-32       Guangdong
# 92676         29-32        Zhejiang
# 1060688       29-32           Hebei
# 1084390       23-26       Guangdong
# 816924        33-38        Shandong
# 1007917         39+           Hebei
# 785678          39+         Beijing
# 830953        23-26         Jiangsu
# 377196          39+       Guangdong
# 235220          22-       Guangdong
# 1196569       23-26        Zhejiang
# 1236503       33-38           Henan
# 169153        33-38         Jiangsu
# 379729        33-38           Hunan
# 245130          39+       Chongqing
# 1243569         39+         Sichuan
# 801333        33-38           Henan
# 1239852         22-       Guangdong
# 114436          39+        Zhejiang
# 322461        23-26         Sichuan
# 972011        23-26          Shanxi
# 382600          22-  Inner Mongolia
# 308532        23-26         Jiangsu
# 420969          39+         Jiangsu
# 920682          39+           Henan
# 313317          39+       Chongqing
# 895925        29-32         Beijing
# 487165        29-32           Hubei
# 859085        29-32         Jiangsu
# 1257499       29-32           Anhui
# 958436        23-26        Shandong
# 750988          22-       Guangdong
# 348120          22-       Guangdong
# 1133333       29-32           other
# 657903        23-26         Tianjin
# 1087521       29-32        Shandong
# 1077656       33-38         Beijing
# 970372        23-26  Inner Mongolia
# 991867        23-26       Guangdong
# 231921        23-26       Guangdong
# 1128470         22-           Hunan
# 1009314         39+       Chongqing
# 969198        29-32         Tianjin
# 362726        23-26        Zhejiang
# 1044099         39+  Inner Mongolia
# 1072618       29-32         Sichuan
# 380034          39+           Hebei
# 786254        29-32         Sichuan
# 769880          39+           Hubei
